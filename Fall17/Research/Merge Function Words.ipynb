# %%
import numpy as np
import pandas as pd
import pickle

# %%
Pickle_Names = ["D:\\Research\\Data\\FunctionWord_Parallel_0_10000.PICKLE", "D:\\Research\\Data\\FunctionWord_Parallel_10001_20000.PICKLE", \
               "D:\\Research\\Data\\FunctionWord_Parallel_30001_40001.PICKLE", "D:\\Research\\Data\\FunctionWord_Parallel_50001_60001.PICKLE", \
               "D:\\Research\\Data\\FunctionWord_Parallel_60001_70001.PICKLE", "D:\\Research\\Data\\FunctionWord_Parallel_70001_80001.PICKLE", \
               "D:\\Research\\Data\\FunctionWord_Parallel_80001_90001.PICKLE", "D:\\Research\\Data\\FunctionWord_Parallel_90001_100001.PICKLE", \
               "D:\\Research\\Data\\FunctionWord_Parallel_100001_110001.PICKLE", "D:\\Research\\Data\\FunctionWord_Parallel_110001_120001.PICKLE", \
               "D:\\Research\\Data\\FunctionWord_Parallel_120001_130001.PICKLE", "D:\\Research\\Data\\FunctionWord_Parallel_130001_140001.PICKLE", \
               "D:\\Research\\Data\\FunctionWord_Parallel_140001_150001.PICKLE", "D:\\Research\\Data\\FunctionWord_Parallel_150001_160001.PICKLE", \
               "D:\\Research\\Data\\FunctionWord_Parallel_160001_170001.PICKLE", "D:\\Research\\Data\\FunctionWord_Parallel_170001_180001.PICKLE", \
               "D:\\Research\\Data\\FunctionWord_Parallel_180001_190001.PICKLE", "D:\\Research\\Data\\FunctionWord_Parallel_190001_200001.PICKLE", \
               "D:\\Research\\Data\\FunctionWord_Parallel_210001_220001.PICKLE", "D:\\Research\\Data\\FunctionWord_Parallel_220001_230001.PICKLE"]

# %%
Function_Words = {}

# %%
def Get_Dictionary(tst):
    for _, dfs in enumerate(tst):
        if((dfs is not None) & (type(dfs) == pd.core.frame.DataFrame)):
            dictionary = dfs.set_index("Word").T.to_dict('list')
    return dictionary

# %%
def CreateFuncWords(fileName):
    tst = pd.read_pickle(fileName)
    temp_dic = Get_Dictionary(tst)
    print(len(Function_Words))
    Function_Words.update(temp_dic)
    return Function_Words

# %%
for names in Pickle_Names:
    CreateFuncWords(names)
# Out:
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:891: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "columns will be omitted.", UserWarning)
# 60
# 60
# 60
# 74
# 95
# 103
# 124
# 140
# 163
# 183
# 204
# 213
# 234
# 240
# 259
# 283
# 292
# 306
# 312
# 319

# %%
Function_Words
# Out:
# {'a black': [0.0996377, 2374.0, '\\\\\\\\N'],
#  'a challenge': [0.0526473, 10054.0, '\\\\\\\\N'],
#  'a coherent': [0.0933735, 1865.0, '\\\\\\\\N'],
#  'a distinct': [0.0790113, 27895.0, '\\\\\\\\N'],
#  'a dose': [0.0933939, 118615.0, '\\\\\\\\N'],
#  'a focus': [0.0572574, 6259.0, '\\\\\\\\N'],
#  'a framework': [0.07656510000000001, 7659.0, '\\\\\\\\N'],
#  'a guide': [0.0477347, 6913.0, '\\\\\\\\N'],
#  'a high': [0.0646276, 241235.0, '\\\\\\\\N'],
#  'a highly': [0.0838727, 57792.0, '\\\\\\\\N'],
#  'a multitude': [0.0738007, 2809.0, '\\\\\\\\N'],
#  'a national': [0.0958378, 16549.0, '\\\\\\\\N'],
#  'a p': [0.0866995, 13458.0, '\\\\\\\\N'],
#  'a pharmacologic': [0.072716, 883.0, '\\\\\\\\N'],
#  'a red': [0.07168250000000001, 3213.0, '\\\\\\\\N'],
#  'a significant': [0.052840899999999996, 334358.0, '\\\\\\\\N'],
#  'a special': [0.0470566, 20053.0, '\\\\\\\\N'],
#  'a striking': [0.0759931, 10120.0, '\\\\\\\\N'],
#  'a superficial': [0.0941704, 2211.0, '\\\\\\\\N'],
#  'a tentative': [0.0651075, 2112.0, '\\\\\\\\N'],
#  'a variety': [0.0595089, 123076.0, '\\\\\\\\N'],
#  'about': [-1.0, 0.0, 'None'],
#  'accumulate': [0.09320369999999999, 29329.0, '\\\\\\\\N'],
#  'after': [-1.0, 0.0, 'None'],
#  'again': [-1.0, 0.0, 'None'],
#  'against': [-1.0, 0.0, 'None'],
#  'all': [-1.0, 0.0, 'None'],
#  'allow': [0.06772389999999999, 190478.0, '\\\\\\\\N'],
#  'alone': [-1.0, 0.0, 'None'],
#  'along': [-1.0, 0.0, 'None'],
#  'also': [-1.0, 0.0, 'None'],
#  'although': [-1.0, 0.0, 'None'],
#  'among': [-1.0, 0.0, 'None'],
#  'an': [-1.0, 0.0, 'None'],
#  'and': [-1.0, 0.0, 'None'],
#  'another': [-1.0, 0.0, 'None'],
#  'any': [-1.0, 0.0, 'None'],
#  'apart': [0.0704185, 31046.0, '\\\\\\\\N'],
#  'appear': [0.05596040000000001, 404918.0, '\\\\\\\\N'],
#  'are': [-1.0, 0.0, 'None'],
#  'around': [-1.0, 0.0, 'None'],
#  'article': [0.0817222, 172169.0, '\\\\\\\\N'],
#  'as': [-1.0, 0.0, 'None'],
#  'at': [-1.0, 0.0, 'None'],
#  'based process': [0.0897959, 390.0, '\\\\\\\\N'],
#  'be': [-1.0, 0.0, 'None'],
#  'because': [-1.0, 0.0, 'None'],
#  'been': [-1.0, 0.0, 'None'],
#  'between': [-1.0, 0.0, 'None'],
#  'beyond': [-1.0, 0.0, 'None'],
#  'both': [-1.0, 0.0, 'None'],
#  'brief summary': [0.0754717, 812.0, '\\\\\\\\N'],
#  'build': [0.0762831, 10930.0, '\\\\\\\\N'],
#  'burden': [0.0982767, 28187.0, '\\\\\\\\N'],
#  'but': [-1.0, 0.0, 'None'],
#  'by': [-1.0, 0.0, 'None'],
#  'can': [-1.0, 0.0, 'None'],
#  'caused': [0.0466037, 410931.0, '\\\\\\\\N'],
#  'challenging': [0.0723167, 13350.0, '\\\\\\\\N'],
#  'characterized': [0.0627896, 262275.0, '\\\\\\\\N'],
#  'clarified': [0.060434400000000006, 12389.0, '\\\\\\\\N'],
#  'close a': [0.0666667, 1947.0, '\\\\\\\\N'],
#  'commensurate': [0.0869565, 1803.0, '\\\\\\\\N'],
#  'complicate': [0.051106, 6733.0, '\\\\\\\\N'],
#  'considered': [0.056444100000000004, 300594.0, '\\\\\\\\N'],
#  'constitute a': [0.0879828, 20848.0, '\\\\\\\\N'],
#  'continue': [0.059842, 63595.0, '\\\\\\\\N'],
#  'contributing factor': [0.0659006, 5984.0, '\\\\\\\\N'],
#  'contribution': [0.0425955, 137237.0, '\\\\\\\\N'],
#  'coordinated': [0.056211000000000004, 16093.0, '\\\\\\\\N'],
#  'coordinating': [0.0650244, 4354.0, '\\\\\\\\N'],
#  'correlate': [0.0645696, 116597.0, '\\\\\\\\N'],
#  'correlation': [0.0605379, 345589.0, '\\\\\\\\N'],
#  'correspond': [0.0747362, 44781.0, '\\\\\\\\N'],
#  'cycling': [0.09701439999999999, 16349.0, '\\\\\\\\N'],
#  'data': [0.0802932, 1032989.0, '\\\\\\\\N'],
#  'data concerning': [0.052941199999999994, 6467.0, '\\\\\\\\N'],
#  'de': [-1.0, 0.0, 'None'],
#  'defined': [0.0867114, 207898.0, '\\\\\\\\N'],
#  'definition': [0.0537101, 48167.0, '\\\\\\\\N'],
#  'delivered': [0.05728300000000001, 48353.0, '\\\\\\\\N'],
#  'demonstrate': [0.060315499999999994, 323592.0, '\\\\\\\\N'],
#  'depend': [-1.0, 0.0, 'None'],
#  'depending': [0.051855700000000005, 73858.0, '\\\\\\\\N'],
#  'describe': [0.0696355, 251258.0, '\\\\\\\\N'],
#  'designed': [0.0849336, 145397.0, '\\\\\\\\N'],
#  'determining': [0.051134, 98159.0, '\\\\\\\\N'],
#  'did': [-1.0, 0.0, 'None'],
#  'difficulty': [0.0653927, 82608.0, '\\\\\\\\N'],
#  'dilemma': [0.0792339, 13981.0, '\\\\\\\\N'],
#  'discuss': [0.07257430000000001, 91045.0, '\\\\\\\\N'],
#  'discussed': [0.0776197, 377113.0, '\\\\\\\\N'],
#  'display a': [0.09597689999999999, 12534.0, '\\\\\\\\N'],
#  'distinction': [0.0509141, 20440.0, '\\\\\\\\N'],
#  'distinguishing': [0.059968600000000004, 15989.0, '\\\\\\\\N'],
#  'diverse array': [0.08333330000000001, 818.0, '\\\\\\\\N'],
#  'divided': [0.08139149999999999, 106579.0, '\\\\\\\\N'],
#  'do': [-1.0, 0.0, 'None'],
#  'dual': [0.06326509999999999, 46369.0, '\\\\\\\\N'],
#  'due': [-1.0, 0.0, 'None'],
#  'during': [-1.0, 0.0, 'None'],
#  'each': [-1.0, 0.0, 'None'],
#  'ec': [-1.0, 0.0, 'None'],
#  'effective concentration': [0.08783780000000001, 4550.0, '\\\\\\\\N'],
#  'efficacious treatment': [0.0995261, 1309.0, '\\\\\\\\N'],
#  'efficacy': [0.0936715, 207478.0, '\\\\\\\\N'],
#  'eg': [-1.0, 0.0, 'None'],
#  'emphasize': [0.06125459999999999, 35199.0, '\\\\\\\\N'],
#  'emphasizing': [0.06406970000000001, 7296.0, '\\\\\\\\N'],
#  'enough': [-1.0, 0.0, 'None'],
#  'ensure': [0.0475244, 36659.0, '\\\\\\\\N'],
#  'ensuring': [0.0638201, 8143.0, '\\\\\\\\N'],
#  'especially': [-1.0, 0.0, 'None'],
#  'evaluative': [0.0987612, 2274.0, '\\\\\\\\N'],
#  'evidence': [0.059623699999999995, 533097.0, '\\\\\\\\N'],
#  'example': [0.0426135, 113689.0, '\\\\\\\\N'],
#  'exert': [0.0785845, 53443.0, '\\\\\\\\N'],
#  'existing': [0.0452392, 60483.0, '\\\\\\\\N'],
#  'expand': [0.053302999999999996, 14483.0, '\\\\\\\\N'],
#  'experience a': [0.074778, 19639.0, '\\\\\\\\N'],
#  'experience study': [0.0619369, 543.0, '\\\\\\\\N'],
#  'experience trial': [0.08333330000000001, 68.0, '\\\\\\\\N'],
#  'explain': [0.05148330000000001, 98782.0, '\\\\\\\\N'],
#  'explained': [0.0497096, 76974.0, '\\\\\\\\N'],
#  'extended': [0.0777678, 80097.0, '\\\\\\\\N'],
#  'few': [0.039252499999999996, 189016.0, '\\\\\\\\N'],
#  'five': [0.05747909999999999, 429337.0, '\\\\\\\\N'],
#  'for': [-1.0, 0.0, 'None'],
#  'framework': [0.0619607, 41292.0, '\\\\\\\\N'],
#  'from': [-1.0, 0.0, 'None'],
#  'frontier': [0.0600349, 3142.0, '\\\\\\\\N'],
#  'functional behavior': [0.07275319999999999, 521.0, '\\\\\\\\N'],
#  'further': [-1.0, 0.0, 'None'],
#  'general principle': [0.051602300000000004, 2811.0, '\\\\\\\\N'],
#  'give': [-1.0, 0.0, 'None'],
#  'given': [0.0666795, 346034.0, '\\\\\\\\N'],
#  'has': [-1.0, 0.0, 'None'],
#  'have': [-1.0, 0.0, 'None'],
#  'highlight': [0.0718306, 30320.0, '\\\\\\\\N'],
#  'hour a': [0.0687876, 9274.0, '\\\\\\\\N'],
#  'how': [-1.0, 0.0, 'None'],
#  'however': [-1.0, 0.0, 'None'],
#  'identified': [0.0882119, 456810.0, '\\\\\\\\N'],
#  'if': [-1.0, 0.0, 'None'],
#  'implied': [0.0795455, 6072.0, '\\\\\\\\N'],
#  'important': [-1.0, 0.0, 'None'],
#  'improve': [0.0590557, 178728.0, '\\\\\\\\N'],
#  'in': [-1.0, 0.0, 'None'],
#  'include': [0.0739127, 225277.0, '\\\\\\\\N'],
#  'incorporate': [0.0634528, 19192.0, '\\\\\\\\N'],
#  'increased severity': [0.0909091, 1719.0, '\\\\\\\\N'],
#  'indicate': [0.0673351, 587230.0, '\\\\\\\\N'],
#  'indispensable': [0.06499540000000001, 7750.0, '\\\\\\\\N'],
#  'influence': [0.055067200000000004, 403550.0, '\\\\\\\\N'],
#  'inherent': [0.0453226, 20788.0, '\\\\\\\\N'],
#  'inhibit': [0.09434, 201810.0, '\\\\\\\\N'],
#  'interfere': [0.0713763, 36249.0, '\\\\\\\\N'],
#  'international': [0.09944910000000001, 72932.0, '\\\\\\\\N'],
#  'into': [-1.0, 0.0, 'None'],
#  'introduced': [0.0710355, 73178.0, '\\\\\\\\N'],
#  'investigate': [-1.0, 0.0, 'None'],
#  'involved': [0.08880249999999999, 407011.0, '\\\\\\\\N'],
#  'is': [-1.0, 0.0, 'None'],
#  'it': [-1.0, 0.0, 'None'],
#  'its': [-1.0, 0.0, 'None'],
#  'itself': [-1.0, 0.0, 'None'],
#  'justify': [0.08385089999999999, 11701.0, '\\\\\\\\N'],
#  'justifying': [0.0871413, 1359.0, '\\\\\\\\N'],
#  'keep': [-1.0, 0.0, 'None'],
#  'km': [-1.0, 0.0, 'None'],
#  'last': [-1.0, 0.0, 'None'],
#  'lend': [0.0640496, 7656.0, '\\\\\\\\N'],
#  'less': [0.0713288, 0.0, '\\\\\\\\N'],
#  'liberate': [0.0794798, 1678.0, '\\\\\\\\N'],
#  'low concentration': [0.0653792, 32147.0, '\\\\\\\\N'],
#  'made': [-1.0, 0.0, 'None'],
#  'mainstay': [0.0684932, 4255.0, '\\\\\\\\N'],
#  'maintain': [0.0542143, 66674.0, '\\\\\\\\N'],
#  'maintained': [0.069827, 115070.0, '\\\\\\\\N'],
#  'major medical': [0.0810811, 1093.0, '\\\\\\\\N'],
#  'many': [-1.0, 0.0, 'None'],
#  'maximize': [0.058043899999999995, 9191.0, '\\\\\\\\N'],
#  'may': [-1.0, 0.0, 'None'],
#  'me': [-1.0, 0.0, 'None'],
#  'might': [-1.0, 0.0, 'None'],
#  'mm': [-1.0, 0.0, 'None'],
#  'monitored': [0.0632618, 80685.0, '\\\\\\\\N'],
#  'monitoring': [0.0810219, 139454.0, '\\\\\\\\N'],
#  'more': [-1.0, 0.0, 'None'],
#  'most': [-1.0, 0.0, 'None'],
#  'much': [-1.0, 0.0, 'None'],
#  'needed': [0.058239, 132754.0, '\\\\\\\\N'],
#  'next': [-1.0, 0.0, 'None'],
#  'no': [-1.0, 0.0, 'None'],
#  'observed a': [0.057517099999999995, 42770.0, '\\\\\\\\N'],
#  'obviously': [0.0921986, 11875.0, '\\\\\\\\N'],
#  'occur': [0.0691008, 356210.0, '\\\\\\\\N'],
#  'occur late': [0.0964467, 1202.0, '\\\\\\\\N'],
#  'of': [-1.0, 0.0, 'None'],
#  'off': [-1.0, 0.0, 'None'],
#  'often': [-1.0, 0.0, 'None'],
#  'on': [-1.0, 0.0, 'None'],
#  'only': [-1.0, 0.0, 'None'],
#  'optimal': [0.06367919999999999, 103720.0, '\\\\\\\\N'],
#  'order': [0.048364300000000006, 350940.0, '\\\\\\\\N'],
#  'organize': [0.0619649, 4444.0, '\\\\\\\\N'],
#  'other': [-1.0, 0.0, 'None'],
#  'our': [-1.0, 0.0, 'None'],
#  'out': [-1.0, 0.0, 'None'],
#  'overall': [-1.0, 0.0, 'None'],
#  'override': [0.0923451, 1761.0, '\\\\\\\\N'],
#  'particularly': [-1.0, 0.0, 'None'],
#  'patient or': [0.0861154, 30488.0, '\\\\\\\\N'],
#  'perpetual': [0.07126439999999999, 305.0, '\\\\\\\\N'],
#  'potential complication': [0.0676507, 3080.0, '\\\\\\\\N'],
#  'practical issue': [0.0923077, 810.0, '\\\\\\\\N'],
#  'practical measure': [0.0972973, 279.0, '\\\\\\\\N'],
#  'preparing': [0.070855, 11168.0, '\\\\\\\\N'],
#  'present': [-1.0, 0.0, 'None'],
#  'presented': [0.0904956, 376182.0, '\\\\\\\\N'],
#  'prevent': [0.0582866, 157309.0, '\\\\\\\\N'],
#  'primarily': [-1.0, 0.0, 'None'],
#  'principle': [0.0453819, 83592.0, '\\\\\\\\N'],
#  'produced': [0.0687383, 388178.0, '\\\\\\\\N'],
#  'promote': [0.0917806, 78542.0, '\\\\\\\\N'],
#  'proposal': [0.0555124, 21887.0, '\\\\\\\\N'],
#  'proposed': [0.0497315, 177671.0, '\\\\\\\\N'],
#  'prospect': [0.0660952, 18236.0, '\\\\\\\\N'],
#  'provide': [0.0473096, 477400.0, '\\\\\\\\N'],
#  'provide a': [0.0679482, 134214.0, '\\\\\\\\N'],
#  'provide additional': [0.0849515, 9238.0, '\\\\\\\\N'],
#  'provided': [0.0556345, 179961.0, '\\\\\\\\N'],
#  'purified': [0.0885285, 192162.0, '\\\\\\\\N'],
#  'range': [0.0712062, 412046.0, '\\\\\\\\N'],
#  'rationale': [0.0730009, 24445.0, '\\\\\\\\N'],
#  'really': [-1.0, 0.0, 'None'],
#  'received': [0.0654628, 253238.0, '\\\\\\\\N'],
#  'receiving': [0.0790921, 118242.0, '\\\\\\\\N'],
#  'recent report': [0.08227849999999999, 8994.0, '\\\\\\\\N'],
#  'recent study': [0.0457658, 40643.0, '\\\\\\\\N'],
#  'recently': [-1.0, 0.0, 'None'],
#  'reconcile': [0.0599078, 2066.0, '\\\\\\\\N'],
#  'reducing': [0.04920069999999999, 101798.0, '\\\\\\\\N'],
#  'reflect': [0.047416900000000005, 106843.0, '\\\\\\\\N'],
#  'reflected': [0.057704, 44089.0, '\\\\\\\\N'],
#  'regarding': [-1.0, 0.0, 'None'],
#  'relatively high': [0.07258060000000001, 22116.0, '\\\\\\\\N'],
#  'remain': [0.0594882, 227627.0, '\\\\\\\\N'],
#  'represent': [0.06116269999999999, 183941.0, '\\\\\\\\N'],
#  'requiring': [0.0797207, 57293.0, '\\\\\\\\N'],
#  'resolve': [0.049935, 16615.0, '\\\\\\\\N'],
#  'responsible': [0.0785346, 180679.0, '\\\\\\\\N'],
#  'resulted': [0.0593857, 293349.0, '\\\\\\\\N'],
#  'revealed': [0.07369550000000001, 498080.0, '\\\\\\\\N'],
#  'reviewed': [0.0979697, 171471.0, '\\\\\\\\N'],
#  'safely': [0.0781848, 19840.0, '\\\\\\\\N'],
#  'same': [-1.0, 0.0, 'None'],
#  'scheme': [0.0723789, 32666.0, '\\\\\\\\N'],
#  'seem': [-1.0, 0.0, 'None'],
#  'selected': [0.0449872, 207419.0, '\\\\\\\\N'],
#  'seriously': [-1.0, 0.0, 'None'],
#  'serve': [0.0487054, 82608.0, '\\\\\\\\N'],
#  'shared': [0.0903889, 31621.0, '\\\\\\\\N'],
#  'should': [-1.0, 0.0, 'None'],
#  'show': [-1.0, 0.0, 'None'],
#  'shown': [-1.0, 0.0, 'None'],
#  'significantly': [-1.0, 0.0, 'None'],
#  'some': [-1.0, 0.0, 'None'],
#  'spite': [0.0428042, 35913.0, '\\\\\\\\N'],
#  'still': [-1.0, 0.0, 'None'],
#  'study site': [0.06918510000000001, 2209.0, '\\\\\\\\N'],
#  'succeed': [0.0577758, 3269.0, '\\\\\\\\N'],
#  'such': [-1.0, 0.0, 'None'],
#  'suffer': [0.0663212, 18134.0, '\\\\\\\\N'],
#  'summarize': [0.0964467, 26470.0, '\\\\\\\\N'],
#  'synthetic': [0.0862378, 105504.0, '\\\\\\\\N'],
#  'test a': [0.0777062, 29310.0, '\\\\\\\\N'],
#  'than': [-1.0, 0.0, 'None'],
#  'that': [-1.0, 0.0, 'None'],
#  'the': [-1.0, 0.0, 'None'],
#  'their': [-1.0, 0.0, 'None'],
#  'them': [-1.0, 0.0, 'None'],
#  'there': [-1.0, 0.0, 'None'],
#  'these': [-1.0, 0.0, 'None'],
#  'they': [-1.0, 0.0, 'None'],
#  'this': [-1.0, 0.0, 'None'],
#  'those': [-1.0, 0.0, 'None'],
#  'though': [-1.0, 0.0, 'None'],
#  'three example': [0.0772201, 747.0, '\\\\\\\\N'],
#  'throughout': [-1.0, 0.0, 'None'],
#  'thus': [-1.0, 0.0, 'None'],
#  'time patient': [0.08047639999999999, 9366.0, '\\\\\\\\N'],
#  'to': [-1.0, 0.0, 'None'],
#  'together': [-1.0, 0.0, 'None'],
#  'too': [-1.0, 0.0, 'None'],
#  'treated': [0.0621226, 645998.0, '\\\\\\\\N'],
#  'trigger': [0.0734106, 32578.0, '\\\\\\\\N'],
#  'two pathway': [0.06857139999999999, 2323.0, '\\\\\\\\N'],
#  'type': [-1.0, 0.0, 'None'],
#  'unclear': [0.0669523, 51838.0, '\\\\\\\\N'],
#  'under': [-1.0, 0.0, 'None'],
#  'underlie': [0.07227330000000001, 13985.0, '\\\\\\\\N'],
#  'understand': [0.0734163, 56666.0, '\\\\\\\\N'],
#  'undertaken': [0.0817439, 73615.0, '\\\\\\\\N'],
#  'unique': [0.0779382, 120423.0, '\\\\\\\\N'],
#  'up': [-1.0, 0.0, 'None'],
#  'use': [-1.0, 0.0, 'None'],
#  'used': [-1.0, 0.0, 'None'],
#  'usually': [-1.0, 0.0, 'None'],
#  'utilizing': [0.0435047, 39974.0, '\\\\\\\\N'],
#  'variety': [0.0477445, 161584.0, '\\\\\\\\N'],
#  'versatility': [0.0686567, 2936.0, '\\\\\\\\N'],
#  'very': [-1.0, 0.0, 'None'],
#  'was': [-1.0, 0.0, 'None'],
#  'we': [-1.0, 0.0, 'None'],
#  'were': [-1.0, 0.0, 'None'],
#  'when': [-1.0, 0.0, 'None'],
#  'where': [-1.0, 0.0, 'None'],
#  'whereas': [-1.0, 0.0, 'None'],
#  'which': [-1.0, 0.0, 'None'],
#  'while': [-1.0, 0.0, 'None'],
#  'who': [-1.0, 0.0, 'None'],
#  'why': [-1.0, 0.0, 'None'],
#  'will': [-1.0, 0.0, 'None'],
#  'with': [-1.0, 0.0, 'None'],
#  'within': [-1.0, 0.0, 'None'],
#  'would': [-1.0, 0.0, 'None']}

# %%
out_file_name =  "D:\\Research\\Data\\FunctionWord_Merged.PICKLE"      
with open(out_file_name, 'wb') as thefile:
        cPickle.dump(Function_Words, thefile)

# %%
with open("D:\\Research\\Data\\FunctionWord_Merged.PICKLE", 'rb') as thefile:
    dict_fw = pickle.load(thefile)

# %%
dict_fw
# Out:
# {'a black': [0.0996377, 2374.0, '\\\\\\\\N'],
#  'a challenge': [0.0526473, 10054.0, '\\\\\\\\N'],
#  'a coherent': [0.0933735, 1865.0, '\\\\\\\\N'],
#  'a distinct': [0.0790113, 27895.0, '\\\\\\\\N'],
#  'a dose': [0.0933939, 118615.0, '\\\\\\\\N'],
#  'a focus': [0.0572574, 6259.0, '\\\\\\\\N'],
#  'a framework': [0.07656510000000001, 7659.0, '\\\\\\\\N'],
#  'a guide': [0.0477347, 6913.0, '\\\\\\\\N'],
#  'a high': [0.0646276, 241235.0, '\\\\\\\\N'],
#  'a highly': [0.0838727, 57792.0, '\\\\\\\\N'],
#  'a multitude': [0.0738007, 2809.0, '\\\\\\\\N'],
#  'a national': [0.0958378, 16549.0, '\\\\\\\\N'],
#  'a p': [0.0866995, 13458.0, '\\\\\\\\N'],
#  'a pharmacologic': [0.072716, 883.0, '\\\\\\\\N'],
#  'a red': [0.07168250000000001, 3213.0, '\\\\\\\\N'],
#  'a significant': [0.052840899999999996, 334358.0, '\\\\\\\\N'],
#  'a special': [0.0470566, 20053.0, '\\\\\\\\N'],
#  'a striking': [0.0759931, 10120.0, '\\\\\\\\N'],
#  'a superficial': [0.0941704, 2211.0, '\\\\\\\\N'],
#  'a tentative': [0.0651075, 2112.0, '\\\\\\\\N'],
#  'a variety': [0.0595089, 123076.0, '\\\\\\\\N'],
#  'about': [-1.0, 0.0, 'None'],
#  'accumulate': [0.09320369999999999, 29329.0, '\\\\\\\\N'],
#  'after': [-1.0, 0.0, 'None'],
#  'again': [-1.0, 0.0, 'None'],
#  'against': [-1.0, 0.0, 'None'],
#  'all': [-1.0, 0.0, 'None'],
#  'allow': [0.06772389999999999, 190478.0, '\\\\\\\\N'],
#  'alone': [-1.0, 0.0, 'None'],
#  'along': [-1.0, 0.0, 'None'],
#  'also': [-1.0, 0.0, 'None'],
#  'although': [-1.0, 0.0, 'None'],
#  'among': [-1.0, 0.0, 'None'],
#  'an': [-1.0, 0.0, 'None'],
#  'and': [-1.0, 0.0, 'None'],
#  'another': [-1.0, 0.0, 'None'],
#  'any': [-1.0, 0.0, 'None'],
#  'apart': [0.0704185, 31046.0, '\\\\\\\\N'],
#  'appear': [0.05596040000000001, 404918.0, '\\\\\\\\N'],
#  'are': [-1.0, 0.0, 'None'],
#  'around': [-1.0, 0.0, 'None'],
#  'article': [0.0817222, 172169.0, '\\\\\\\\N'],
#  'as': [-1.0, 0.0, 'None'],
#  'at': [-1.0, 0.0, 'None'],
#  'based process': [0.0897959, 390.0, '\\\\\\\\N'],
#  'be': [-1.0, 0.0, 'None'],
#  'because': [-1.0, 0.0, 'None'],
#  'been': [-1.0, 0.0, 'None'],
#  'between': [-1.0, 0.0, 'None'],
#  'beyond': [-1.0, 0.0, 'None'],
#  'both': [-1.0, 0.0, 'None'],
#  'brief summary': [0.0754717, 812.0, '\\\\\\\\N'],
#  'build': [0.0762831, 10930.0, '\\\\\\\\N'],
#  'burden': [0.0982767, 28187.0, '\\\\\\\\N'],
#  'but': [-1.0, 0.0, 'None'],
#  'by': [-1.0, 0.0, 'None'],
#  'can': [-1.0, 0.0, 'None'],
#  'caused': [0.0466037, 410931.0, '\\\\\\\\N'],
#  'challenging': [0.0723167, 13350.0, '\\\\\\\\N'],
#  'characterized': [0.0627896, 262275.0, '\\\\\\\\N'],
#  'clarified': [0.060434400000000006, 12389.0, '\\\\\\\\N'],
#  'close a': [0.0666667, 1947.0, '\\\\\\\\N'],
#  'commensurate': [0.0869565, 1803.0, '\\\\\\\\N'],
#  'complicate': [0.051106, 6733.0, '\\\\\\\\N'],
#  'considered': [0.056444100000000004, 300594.0, '\\\\\\\\N'],
#  'constitute a': [0.0879828, 20848.0, '\\\\\\\\N'],
#  'continue': [0.059842, 63595.0, '\\\\\\\\N'],
#  'contributing factor': [0.0659006, 5984.0, '\\\\\\\\N'],
#  'contribution': [0.0425955, 137237.0, '\\\\\\\\N'],
#  'coordinated': [0.056211000000000004, 16093.0, '\\\\\\\\N'],
#  'coordinating': [0.0650244, 4354.0, '\\\\\\\\N'],
#  'correlate': [0.0645696, 116597.0, '\\\\\\\\N'],
#  'correlation': [0.0605379, 345589.0, '\\\\\\\\N'],
#  'correspond': [0.0747362, 44781.0, '\\\\\\\\N'],
#  'cycling': [0.09701439999999999, 16349.0, '\\\\\\\\N'],
#  'data': [0.0802932, 1032989.0, '\\\\\\\\N'],
#  'data concerning': [0.052941199999999994, 6467.0, '\\\\\\\\N'],
#  'de': [-1.0, 0.0, 'None'],
#  'defined': [0.0867114, 207898.0, '\\\\\\\\N'],
#  'definition': [0.0537101, 48167.0, '\\\\\\\\N'],
#  'delivered': [0.05728300000000001, 48353.0, '\\\\\\\\N'],
#  'demonstrate': [0.060315499999999994, 323592.0, '\\\\\\\\N'],
#  'depend': [-1.0, 0.0, 'None'],
#  'depending': [0.051855700000000005, 73858.0, '\\\\\\\\N'],
#  'describe': [0.0696355, 251258.0, '\\\\\\\\N'],
#  'designed': [0.0849336, 145397.0, '\\\\\\\\N'],
#  'determining': [0.051134, 98159.0, '\\\\\\\\N'],
#  'did': [-1.0, 0.0, 'None'],
#  'difficulty': [0.0653927, 82608.0, '\\\\\\\\N'],
#  'dilemma': [0.0792339, 13981.0, '\\\\\\\\N'],
#  'discuss': [0.07257430000000001, 91045.0, '\\\\\\\\N'],
#  'discussed': [0.0776197, 377113.0, '\\\\\\\\N'],
#  'display a': [0.09597689999999999, 12534.0, '\\\\\\\\N'],
#  'distinction': [0.0509141, 20440.0, '\\\\\\\\N'],
#  'distinguishing': [0.059968600000000004, 15989.0, '\\\\\\\\N'],
#  'diverse array': [0.08333330000000001, 818.0, '\\\\\\\\N'],
#  'divided': [0.08139149999999999, 106579.0, '\\\\\\\\N'],
#  'do': [-1.0, 0.0, 'None'],
#  'dual': [0.06326509999999999, 46369.0, '\\\\\\\\N'],
#  'due': [-1.0, 0.0, 'None'],
#  'during': [-1.0, 0.0, 'None'],
#  'each': [-1.0, 0.0, 'None'],
#  'ec': [-1.0, 0.0, 'None'],
#  'effective concentration': [0.08783780000000001, 4550.0, '\\\\\\\\N'],
#  'efficacious treatment': [0.0995261, 1309.0, '\\\\\\\\N'],
#  'efficacy': [0.0936715, 207478.0, '\\\\\\\\N'],
#  'eg': [-1.0, 0.0, 'None'],
#  'emphasize': [0.06125459999999999, 35199.0, '\\\\\\\\N'],
#  'emphasizing': [0.06406970000000001, 7296.0, '\\\\\\\\N'],
#  'enough': [-1.0, 0.0, 'None'],
#  'ensure': [0.0475244, 36659.0, '\\\\\\\\N'],
#  'ensuring': [0.0638201, 8143.0, '\\\\\\\\N'],
#  'especially': [-1.0, 0.0, 'None'],
#  'evaluative': [0.0987612, 2274.0, '\\\\\\\\N'],
#  'evidence': [0.059623699999999995, 533097.0, '\\\\\\\\N'],
#  'example': [0.0426135, 113689.0, '\\\\\\\\N'],
#  'exert': [0.0785845, 53443.0, '\\\\\\\\N'],
#  'existing': [0.0452392, 60483.0, '\\\\\\\\N'],
#  'expand': [0.053302999999999996, 14483.0, '\\\\\\\\N'],
#  'experience a': [0.074778, 19639.0, '\\\\\\\\N'],
#  'experience study': [0.0619369, 543.0, '\\\\\\\\N'],
#  'experience trial': [0.08333330000000001, 68.0, '\\\\\\\\N'],
#  'explain': [0.05148330000000001, 98782.0, '\\\\\\\\N'],
#  'explained': [0.0497096, 76974.0, '\\\\\\\\N'],
#  'extended': [0.0777678, 80097.0, '\\\\\\\\N'],
#  'few': [0.039252499999999996, 189016.0, '\\\\\\\\N'],
#  'five': [0.05747909999999999, 429337.0, '\\\\\\\\N'],
#  'for': [-1.0, 0.0, 'None'],
#  'framework': [0.0619607, 41292.0, '\\\\\\\\N'],
#  'from': [-1.0, 0.0, 'None'],
#  'frontier': [0.0600349, 3142.0, '\\\\\\\\N'],
#  'functional behavior': [0.07275319999999999, 521.0, '\\\\\\\\N'],
#  'further': [-1.0, 0.0, 'None'],
#  'general principle': [0.051602300000000004, 2811.0, '\\\\\\\\N'],
#  'give': [-1.0, 0.0, 'None'],
#  'given': [0.0666795, 346034.0, '\\\\\\\\N'],
#  'has': [-1.0, 0.0, 'None'],
#  'have': [-1.0, 0.0, 'None'],
#  'highlight': [0.0718306, 30320.0, '\\\\\\\\N'],
#  'hour a': [0.0687876, 9274.0, '\\\\\\\\N'],
#  'how': [-1.0, 0.0, 'None'],
#  'however': [-1.0, 0.0, 'None'],
#  'identified': [0.0882119, 456810.0, '\\\\\\\\N'],
#  'if': [-1.0, 0.0, 'None'],
#  'implied': [0.0795455, 6072.0, '\\\\\\\\N'],
#  'important': [-1.0, 0.0, 'None'],
#  'improve': [0.0590557, 178728.0, '\\\\\\\\N'],
#  'in': [-1.0, 0.0, 'None'],
#  'include': [0.0739127, 225277.0, '\\\\\\\\N'],
#  'incorporate': [0.0634528, 19192.0, '\\\\\\\\N'],
#  'increased severity': [0.0909091, 1719.0, '\\\\\\\\N'],
#  'indicate': [0.0673351, 587230.0, '\\\\\\\\N'],
#  'indispensable': [0.06499540000000001, 7750.0, '\\\\\\\\N'],
#  'influence': [0.055067200000000004, 403550.0, '\\\\\\\\N'],
#  'inherent': [0.0453226, 20788.0, '\\\\\\\\N'],
#  'inhibit': [0.09434, 201810.0, '\\\\\\\\N'],
#  'interfere': [0.0713763, 36249.0, '\\\\\\\\N'],
#  'international': [0.09944910000000001, 72932.0, '\\\\\\\\N'],
#  'into': [-1.0, 0.0, 'None'],
#  'introduced': [0.0710355, 73178.0, '\\\\\\\\N'],
#  'investigate': [-1.0, 0.0, 'None'],
#  'involved': [0.08880249999999999, 407011.0, '\\\\\\\\N'],
#  'is': [-1.0, 0.0, 'None'],
#  'it': [-1.0, 0.0, 'None'],
#  'its': [-1.0, 0.0, 'None'],
#  'itself': [-1.0, 0.0, 'None'],
#  'justify': [0.08385089999999999, 11701.0, '\\\\\\\\N'],
#  'justifying': [0.0871413, 1359.0, '\\\\\\\\N'],
#  'keep': [-1.0, 0.0, 'None'],
#  'km': [-1.0, 0.0, 'None'],
#  'last': [-1.0, 0.0, 'None'],
#  'lend': [0.0640496, 7656.0, '\\\\\\\\N'],
#  'less': [0.0713288, 0.0, '\\\\\\\\N'],
#  'liberate': [0.0794798, 1678.0, '\\\\\\\\N'],
#  'low concentration': [0.0653792, 32147.0, '\\\\\\\\N'],
#  'made': [-1.0, 0.0, 'None'],
#  'mainstay': [0.0684932, 4255.0, '\\\\\\\\N'],
#  'maintain': [0.0542143, 66674.0, '\\\\\\\\N'],
#  'maintained': [0.069827, 115070.0, '\\\\\\\\N'],
#  'major medical': [0.0810811, 1093.0, '\\\\\\\\N'],
#  'many': [-1.0, 0.0, 'None'],
#  'maximize': [0.058043899999999995, 9191.0, '\\\\\\\\N'],
#  'may': [-1.0, 0.0, 'None'],
#  'me': [-1.0, 0.0, 'None'],
#  'might': [-1.0, 0.0, 'None'],
#  'mm': [-1.0, 0.0, 'None'],
#  'monitored': [0.0632618, 80685.0, '\\\\\\\\N'],
#  'monitoring': [0.0810219, 139454.0, '\\\\\\\\N'],
#  'more': [-1.0, 0.0, 'None'],
#  'most': [-1.0, 0.0, 'None'],
#  'much': [-1.0, 0.0, 'None'],
#  'needed': [0.058239, 132754.0, '\\\\\\\\N'],
#  'next': [-1.0, 0.0, 'None'],
#  'no': [-1.0, 0.0, 'None'],
#  'observed a': [0.057517099999999995, 42770.0, '\\\\\\\\N'],
#  'obviously': [0.0921986, 11875.0, '\\\\\\\\N'],
#  'occur': [0.0691008, 356210.0, '\\\\\\\\N'],
#  'occur late': [0.0964467, 1202.0, '\\\\\\\\N'],
#  'of': [-1.0, 0.0, 'None'],
#  'off': [-1.0, 0.0, 'None'],
#  'often': [-1.0, 0.0, 'None'],
#  'on': [-1.0, 0.0, 'None'],
#  'only': [-1.0, 0.0, 'None'],
#  'optimal': [0.06367919999999999, 103720.0, '\\\\\\\\N'],
#  'order': [0.048364300000000006, 350940.0, '\\\\\\\\N'],
#  'organize': [0.0619649, 4444.0, '\\\\\\\\N'],
#  'other': [-1.0, 0.0, 'None'],
#  'our': [-1.0, 0.0, 'None'],
#  'out': [-1.0, 0.0, 'None'],
#  'overall': [-1.0, 0.0, 'None'],
#  'override': [0.0923451, 1761.0, '\\\\\\\\N'],
#  'particularly': [-1.0, 0.0, 'None'],
#  'patient or': [0.0861154, 30488.0, '\\\\\\\\N'],
#  'perpetual': [0.07126439999999999, 305.0, '\\\\\\\\N'],
#  'potential complication': [0.0676507, 3080.0, '\\\\\\\\N'],
#  'practical issue': [0.0923077, 810.0, '\\\\\\\\N'],
#  'practical measure': [0.0972973, 279.0, '\\\\\\\\N'],
#  'preparing': [0.070855, 11168.0, '\\\\\\\\N'],
#  'present': [-1.0, 0.0, 'None'],
#  'presented': [0.0904956, 376182.0, '\\\\\\\\N'],
#  'prevent': [0.0582866, 157309.0, '\\\\\\\\N'],
#  'primarily': [-1.0, 0.0, 'None'],
#  'principle': [0.0453819, 83592.0, '\\\\\\\\N'],
#  'produced': [0.0687383, 388178.0, '\\\\\\\\N'],
#  'promote': [0.0917806, 78542.0, '\\\\\\\\N'],
#  'proposal': [0.0555124, 21887.0, '\\\\\\\\N'],
#  'proposed': [0.0497315, 177671.0, '\\\\\\\\N'],
#  'prospect': [0.0660952, 18236.0, '\\\\\\\\N'],
#  'provide': [0.0473096, 477400.0, '\\\\\\\\N'],
#  'provide a': [0.0679482, 134214.0, '\\\\\\\\N'],
#  'provide additional': [0.0849515, 9238.0, '\\\\\\\\N'],
#  'provided': [0.0556345, 179961.0, '\\\\\\\\N'],
#  'purified': [0.0885285, 192162.0, '\\\\\\\\N'],
#  'range': [0.0712062, 412046.0, '\\\\\\\\N'],
#  'rationale': [0.0730009, 24445.0, '\\\\\\\\N'],
#  'really': [-1.0, 0.0, 'None'],
#  'received': [0.0654628, 253238.0, '\\\\\\\\N'],
#  'receiving': [0.0790921, 118242.0, '\\\\\\\\N'],
#  'recent report': [0.08227849999999999, 8994.0, '\\\\\\\\N'],
#  'recent study': [0.0457658, 40643.0, '\\\\\\\\N'],
#  'recently': [-1.0, 0.0, 'None'],
#  'reconcile': [0.0599078, 2066.0, '\\\\\\\\N'],
#  'reducing': [0.04920069999999999, 101798.0, '\\\\\\\\N'],
#  'reflect': [0.047416900000000005, 106843.0, '\\\\\\\\N'],
#  'reflected': [0.057704, 44089.0, '\\\\\\\\N'],
#  'regarding': [-1.0, 0.0, 'None'],
#  'relatively high': [0.07258060000000001, 22116.0, '\\\\\\\\N'],
#  'remain': [0.0594882, 227627.0, '\\\\\\\\N'],
#  'represent': [0.06116269999999999, 183941.0, '\\\\\\\\N'],
#  'requiring': [0.0797207, 57293.0, '\\\\\\\\N'],
#  'resolve': [0.049935, 16615.0, '\\\\\\\\N'],
#  'responsible': [0.0785346, 180679.0, '\\\\\\\\N'],
#  'resulted': [0.0593857, 293349.0, '\\\\\\\\N'],
#  'revealed': [0.07369550000000001, 498080.0, '\\\\\\\\N'],
#  'reviewed': [0.0979697, 171471.0, '\\\\\\\\N'],
#  'safely': [0.0781848, 19840.0, '\\\\\\\\N'],
#  'same': [-1.0, 0.0, 'None'],
#  'scheme': [0.0723789, 32666.0, '\\\\\\\\N'],
#  'seem': [-1.0, 0.0, 'None'],
#  'selected': [0.0449872, 207419.0, '\\\\\\\\N'],
#  'seriously': [-1.0, 0.0, 'None'],
#  'serve': [0.0487054, 82608.0, '\\\\\\\\N'],
#  'shared': [0.0903889, 31621.0, '\\\\\\\\N'],
#  'should': [-1.0, 0.0, 'None'],
#  'show': [-1.0, 0.0, 'None'],
#  'shown': [-1.0, 0.0, 'None'],
#  'significantly': [-1.0, 0.0, 'None'],
#  'some': [-1.0, 0.0, 'None'],
#  'spite': [0.0428042, 35913.0, '\\\\\\\\N'],
#  'still': [-1.0, 0.0, 'None'],
#  'study site': [0.06918510000000001, 2209.0, '\\\\\\\\N'],
#  'succeed': [0.0577758, 3269.0, '\\\\\\\\N'],
#  'such': [-1.0, 0.0, 'None'],
#  'suffer': [0.0663212, 18134.0, '\\\\\\\\N'],
#  'summarize': [0.0964467, 26470.0, '\\\\\\\\N'],
#  'synthetic': [0.0862378, 105504.0, '\\\\\\\\N'],
#  'test a': [0.0777062, 29310.0, '\\\\\\\\N'],
#  'than': [-1.0, 0.0, 'None'],
#  'that': [-1.0, 0.0, 'None'],
#  'the': [-1.0, 0.0, 'None'],
#  'their': [-1.0, 0.0, 'None'],
#  'them': [-1.0, 0.0, 'None'],
#  'there': [-1.0, 0.0, 'None'],
#  'these': [-1.0, 0.0, 'None'],
#  'they': [-1.0, 0.0, 'None'],
#  'this': [-1.0, 0.0, 'None'],
#  'those': [-1.0, 0.0, 'None'],
#  'though': [-1.0, 0.0, 'None'],
#  'three example': [0.0772201, 747.0, '\\\\\\\\N'],
#  'throughout': [-1.0, 0.0, 'None'],
#  'thus': [-1.0, 0.0, 'None'],
#  'time patient': [0.08047639999999999, 9366.0, '\\\\\\\\N'],
#  'to': [-1.0, 0.0, 'None'],
#  'together': [-1.0, 0.0, 'None'],
#  'too': [-1.0, 0.0, 'None'],
#  'treated': [0.0621226, 645998.0, '\\\\\\\\N'],
#  'trigger': [0.0734106, 32578.0, '\\\\\\\\N'],
#  'two pathway': [0.06857139999999999, 2323.0, '\\\\\\\\N'],
#  'type': [-1.0, 0.0, 'None'],
#  'unclear': [0.0669523, 51838.0, '\\\\\\\\N'],
#  'under': [-1.0, 0.0, 'None'],
#  'underlie': [0.07227330000000001, 13985.0, '\\\\\\\\N'],
#  'understand': [0.0734163, 56666.0, '\\\\\\\\N'],
#  'undertaken': [0.0817439, 73615.0, '\\\\\\\\N'],
#  'unique': [0.0779382, 120423.0, '\\\\\\\\N'],
#  'up': [-1.0, 0.0, 'None'],
#  'use': [-1.0, 0.0, 'None'],
#  'used': [-1.0, 0.0, 'None'],
#  'usually': [-1.0, 0.0, 'None'],
#  'utilizing': [0.0435047, 39974.0, '\\\\\\\\N'],
#  'variety': [0.0477445, 161584.0, '\\\\\\\\N'],
#  'versatility': [0.0686567, 2936.0, '\\\\\\\\N'],
#  'very': [-1.0, 0.0, 'None'],
#  'was': [-1.0, 0.0, 'None'],
#  'we': [-1.0, 0.0, 'None'],
#  'were': [-1.0, 0.0, 'None'],
#  'when': [-1.0, 0.0, 'None'],
#  'where': [-1.0, 0.0, 'None'],
#  'whereas': [-1.0, 0.0, 'None'],
#  'which': [-1.0, 0.0, 'None'],
#  'while': [-1.0, 0.0, 'None'],
#  'who': [-1.0, 0.0, 'None'],
#  'why': [-1.0, 0.0, 'None'],
#  'will': [-1.0, 0.0, 'None'],
#  'with': [-1.0, 0.0, 'None'],
#  'within': [-1.0, 0.0, 'None'],
#  'would': [-1.0, 0.0, 'None']}
